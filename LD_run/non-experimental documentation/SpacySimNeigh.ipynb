# %%
#You must have SpaCy installed to use this. 
#Note, we use the largest model of SpaCy for improved accuracy and the largest possible vectors

import spacy
import numpy as np
from scipy.spatial import distance

nlp = spacy.load('en_core_web_lg')

# %%
#This script prints the similarity scores, as a matrix, of the tokens you have inserted.
#You can use as many tokens as you would like. For the similarity scores used in the analysis, we only used two.
#Tokens are just words
tokens = nlp (u'God Bless Football')

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# God God 1.0
# God Bless 0.4785873591899872
# God Football -0.06185254454612732
# Bless God 0.4785873591899872
# Bless Bless 1.0
# Bless Football -0.06753934919834137
# Football God -0.06185254454612732
# Football Bless -0.06753934919834137
# Football Football 1.0

# %%
#This script presents the closest 50 words within the tokens vector space. This is how we derive semantic neighbors.
#To derive the 50 closest words, we used words that had complete vectors. Words with empty vectors are low frequency and were not used.
#We also did not use 'compound words'. These are defined as words that appear as a neighbor but are just combinations of real English words, and not actually real English words. 
#For example, stepmother is not a compound word. However, myfriend is. Both appear within the 50 closest neighbors for the word 'wife'
#Similarly, compound words frequently have empty vectors.
#We also avoided proper nouns, except where the word has became a proprietary eponym. An example is within the neighbor list for aspirin, where words like Tylenol and Motrin appear.
#Lastly, frequently, the first 50 words within the vector did not meet these requirements, so the vector size/n= number had to be expanded.
#This is likely due to, in some part, the size of the SpaCy model used. By using the largest library, MANY more words are contained within each vector.
#However, we did not want to introduce a confound where we changed library size to search for neighbors. 

your_word = "necklace"

ms = nlp.vocab.vectors.most_similar(
    np.asarray([nlp.vocab.vectors[nlp.vocab.strings[your_word]]]), n=50)
words = [nlp.vocab.strings[w] for w in ms[0][0]]
distances = ms[2]
print(words)
# Out:
# ['wife', 'mywife', 'wife-', 'husband', 'wifey', 'wife--', 'daughter', "husband'll", 'daughter--', 'daughter-', 'husband-', 'goddaughter', 'Alewife', 'stepdaughter', 'daughtersinlaw', 'husbandman', 'granddaughter', 'alewife', 'grandaughter', 'wifely', 'husband--', 'hotwife', 'daughterinlaw', 'Stepdaughter', 'husbandly', 'Hotwife', 'Dibnah', 'widow', 'husbandmen', 'cousin', 'girlfriend', 'Granddaughter', 'sister', 'Younghusband', "wife'll", 'fiancée', 'Kroeber', 'wifes', 'granddaughters', "father'll", 'daughters', 'mother', 'father-', 'fiancées', 'fiancés', 'father`s', 'son', "father'd", 'niece', 'boyfriend', 'father', 'fiancé', 'sister--', 'fatherwas', 'sister-', 'stepdaughters', 'fiancè', 'fatherinlaw', 'grandmother', 'fianc', 'ladyfriend', 'father--', 'myfriend', 'girlfriend-', 'husbands', 'fiancee', 'girlfriend--', 'stepfather', 'daugher', 'fiancees', 'aunt', 'father"s', 'stepmother', 'househusband', 'grandchild', 'Husband', 'grandmotherly', 'daughterCredit', 'fianceé', 'Befriend',
# ...

# %%
#This script will find the closest neighbor to a given word. It is nearly always the word itself. 
#So, you can use this script to just print the word 'frog' in a complicated way, if you'd like.
input_word = "frog"
p = np.array([nlp.vocab[input_word].vector])
ids = [x for x in nlp.vocab.vectors.keys()]
vectors = [nlp.vocab.vectors[x] for x in ids]
vectors = np.array(vectors)
closest_index = distance.cdist(p, vectors).argmin()
word_id = ids[closest_index]
output_word = nlp.vocab[word_id].text
print(output_word)
# Out:
# frog

# %%
#This script is very similar to the 2nd, in that it finds a words closest neighbors
#The only difference is it will not be accessing it directly from the vector
word = 'jewelry'
nwords = 10
doc = nlp(word)
vector = doc.vector
vect2word = lambda idx: nlp.vocab.strings[idx]
print([vect2word(simword) for simword in nlp.vocab.vectors.most_similar(vector.reshape(1,-1), n=nwords)[0][0]])
# Out:
# ['jewelry', 'jewellery', 'jewellry', 'jewelery', 'jewelries', 'jeweils', 'jeweller', 'jeweler', 'jewellers', 'jeweled']

# %%
pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 43.0 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim.downloader as api

# Load pre-trained GloVe embeddings (50, 100, 200, or 300 dimensions available)
wv = api.load("glove-wiki-gigaword-100")  

# Example: similarity between two words
print("Similarity (blue, red):", wv.similarity("blue", "red"))

# Example: words most similar to "blue"
print(wv.most_similar("blue", topn=5))

# Example: odd-one-out
print("Odd one out:", wv.doesnt_match(["blue", "red", "green", "dog"]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gensim/downloader.py:219, in _load_info(url, encoding)
#     215 try:
#     216     #
#     217     # We need io.open here because Py2 open doesn't support encoding keyword
#     218     #
# --> 219     with io.open(cache_path, 'r', encoding=encoding) as fin:
#     220         return json.load(fin)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/rhardy/gensim-data/information.json'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 import gensim.downloader as api
#       3 # Load pre-trained GloVe embeddings (50, 100, 200, or 300 dimensions available)
# ...

# %%
import os
os.environ["GENSIM_DATA_HOME"] = os.path.expanduser("~/gensim-data")
os.makedirs(os.environ["GENSIM_DATA_HOME"], exist_ok=True)
print("Cache at:", os.environ["GENSIM_DATA_HOME"])
# Out:
# Cache at: /Users/rhardy/gensim-data

# %%
import gensim.downloader as api
info = api.info()            # triggers download of information.json
print("Models available:", list(info["models"].keys())[:5], "…")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gensim/downloader.py:219, in _load_info(url, encoding)
#     215 try:
#     216     #
#     217     # We need io.open here because Py2 open doesn't support encoding keyword
#     218     #
# --> 219     with io.open(cache_path, 'r', encoding=encoding) as fin:
#     220         return json.load(fin)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/rhardy/gensim-data/information.json'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 import gensim.downloader as api
# ----> 2 info = api.info()            # triggers download of information.json
# ...

# %%
import os
os.environ["GENSIM_DATA_HOME"] = os.path.expanduser("~/gensim-data")
os.makedirs(os.environ["GENSIM_DATA_HOME"], exist_ok=True)

# %%
import gensim.downloader as api
info = api.info()  # should now succeed
wv = api.load("glove-wiki-gigaword-100")
print(wv.similarity("god", "football"))
# Out:
# 0.23301145

# %%
import os
os.environ["HTTPS_PROXY"] = "http://user:pass@host:port"
os.environ["HTTP_PROXY"]  = "http://user:pass@host:port"

# %%
import os, shutil, pathlib
os.environ["GENSIM_DATA_HOME"] = os.path.expanduser("~/gensim-data")
pathlib.Path(os.environ["GENSIM_DATA_HOME"]).mkdir(parents=True, exist_ok=True)

# If a broken cache exists, clear it (safe to run)
shutil.rmtree(os.path.join(os.environ["GENSIM_DATA_HOME"], "tmp"), ignore_errors=True)
for f in ("information.json", "README.txt"):
    try: os.remove(os.path.join(os.environ["GENSIM_DATA_HOME"], f))
    except FileNotFoundError: pass
print("Using cache:", os.environ["GENSIM_DATA_HOME"])
# Out:
# Using cache: /Users/rhardy/gensim-data

# %%
# Simple HTTPS fetch; if this fails, your Python environment is blocked
import urllib.request, ssl
print("Trying HTTPS…")
with urllib.request.urlopen("https://example.com", timeout=10, context=ssl.create_default_context()) as r:
    print("OK, status:", r.status)
# Out:
# Trying HTTPS…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:889, in HTTPConnection._get_hostport(self, host, port)
#     888 try:
# --> 889     port = int(host[i+1:])
#     890 except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'port'
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 import urllib.request, ssl
#       3 print("Trying HTTPS…")
# ----> 4 with urllib.request.urlopen("https://example.com", timeout=10, context=ssl.create_default_context()) as r:
#       5     print("OK, status:", r.status)
#
# ...

# %%
import urllib.request, ssl
with urllib.request.urlopen("https://example.com", timeout=10, context=ssl.create_default_context()) as r:
    print("OK, status:", r.status)
# Out:
# OK, status: 200

# %%
import certifi, os
os.environ["SSL_CERT_FILE"] = certifi.where()

# %%
import os
os.environ["GENSIM_DATA_HOME"] = os.path.expanduser("~/gensim-data")
os.makedirs(os.environ["GENSIM_DATA_HOME"], exist_ok=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Cosine similarity between two words
# ----> 2 float(wv.similarity("color", "blue"))
#       4 # Most similar to a word
#       5 wv.most_similar("blue", topn=10)
#
# NameError: name 'wv' is not defined

# %%
import gensim.downloader as api
from numpy import mean

# Load vectors (downloads once, then cached)
wv = api.load("glove-wiki-gigaword-100")

def phrase_vector(phrase, wv):
    words = phrase.lower().split()
    valid = [wv[w] for w in words if w in wv.key_to_index]
    if not valid:
        raise ValueError(f"No in-vocab words in phrase: {phrase}")
    return mean(valid, axis=0)

def phrase_similarity(p1, p2, wv):
    v1, v2 = phrase_vector(p1, wv), phrase_vector(p2, wv)
    # gensim has cosine_similarity built in
    return float(wv.cosine_similarities(v1, [v2])[0])

print("Word sim (republicans, fascism):", wv.similarity("republicans", "fascism"))
print("Phrase sim (charlie kirk, jugular:", phrase_similarity("charlie kirk", "jugular", wv))
# Out:
# Word sim (republicans, fascism): 0.13518806
# Phrase sim (charlie kirk, jugular: -0.05177116021513939
